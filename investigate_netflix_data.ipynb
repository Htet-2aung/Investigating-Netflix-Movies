# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Read in the Netflix CSV as a DataFrame
netflix_df = pd.read_csv("netflix_data.csv")
netflix_df  = netflix_df[netflix_df['release_year'] < 1990]
netflix_df_actions = netflix_df[netflix_df['genre'] == 'Action']
netflix_df_actions
# Out:
#      show_id   type                                              title  \
# 106     s154  Movie                                   A Bridge Too Far
# 188     s268  Movie                                     Aakhri Adaalat
# 271     s392  Movie                                Alibaba Aur 40 Chor
# 309     s447  Movie                                 Amar Akbar Anthony
# 488     s718  Movie                                             Bandie
# 702    s1042  Movie                                   Bonnie and Clyde
# 917    s1415  Movie                                    Cleopatra Jones
# 1126   s1776  Movie                      Disciples Of The 36th Chamber
# 1171   s1836  Movie                             Doubles Cause Troubles
# 1204   s1896  Movie                                             Duniya
# 1247   s1971  Movie                                              Elaan
# 1273   s2014  Movie                                   Enter the Dragon
# ...

# %%
plt.hist(netflix_df_actions["duration"])
plt.title('Distribution of Movie Durations in the 1990s')
plt.xlabel('Duration (minutes)')
plt.ylabel('Number of Movies')
plt.show()

duration = 100

# %%
short_movie_count = 0

# Iterate over the labels and rows of the DataFrame and check if the duration is less than 90, if it is, add 1 to the counter, if it isn't, the counter should remain the same
for label, row in netflix_df_actions.iterrows() :
    if row["duration"] < 90 :
        short_movie_count = short_movie_count + 1
    else:
        short_movie_count = short_movie_count

print(short_movie_count)
# Out:
# 6
